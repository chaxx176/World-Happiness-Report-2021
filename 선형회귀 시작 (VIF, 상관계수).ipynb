# %%
# 정규화 안했을경우 VIF 계수
# 나라는 문자형이라 넣으면 에러
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
df= pd.read_csv("report3_7.csv", header=0)

X = df[['Log GDP per capita','Social support','Healthy life expectancy at birth',\
         'Freedom to make life choices','Generosity','Perceptions of corruption', 'depressive disorders',\
             'schooling','alcohol disorders','suicide rates','Obesity','Fertility', 'Life Ladder','Year']]
vif= pd.DataFrame()
vif["VIF Factor"]= [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"]= X.columns
vif.round(1)
# Out:
#     VIF Factor                          features
# 0        446.9                Log GDP per capita
# 1        120.1                    Social support
# 2        437.7  Healthy life expectancy at birth
# 3         50.6      Freedom to make life choices
# 4          1.3                        Generosity
# 5         27.6         Perceptions of corruption
# 6          1.2              depressive disorders
# 7         30.3                         schooling
# 8          2.3                 alcohol disorders
# 9          6.2                     suicide rates
# 10        10.2                           Obesity
# 11        25.4                         Fertility
# 12       105.6                       Life Ladder
# 13       784.3                              Year

# %%
# 히트맵
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

cm= df[['Log GDP per capita','Social support','Healthy life expectancy at birth',\
         'Freedom to make life choices','Generosity','Perceptions of corruption', 'depressive disorders',\
             'schooling','alcohol disorders','suicide rates','Obesity','Fertility', 'Life Ladder','Year','Country']]
cm= cm.corr()
print(cm)
mask = np.array(cm)
mask[np.tril_indices_from(mask)] = False
fig, ax = plt.subplots()
fig.set_size_inches(20,10)
sns.heatmap(cm, mask=mask,vmax=.8, square=True,annot=True)
# Out:
#                                   Log GDP per capita  Social support  \
# Log GDP per capita                          1.000000        0.677762
# Social support                              0.677762        1.000000
# Healthy life expectancy at birth            0.831653        0.614266
# Freedom to make life choices                0.350144        0.410429
# Generosity                                 -0.012443        0.060608
# Perceptions of corruption                  -0.358590       -0.220657
# depressive disorders                       -0.017390       -0.099335
# schooling                                   0.808098        0.627480
# alcohol disorders                           0.077401        0.221118
# suicide rates                               0.455973        0.380622
# Obesity                                     0.580122        0.401096
# Fertility                                  -0.781835       -0.553439
# Life Ladder                                 0.785219        0.708796
# Year                                        0.084279       -0.012660
#
#                                   Healthy life expectancy at birth  \
# Log GDP per capita                                        0.831653
# Social support                                            0.614266
# Healthy life expectancy at birth                          1.000000
# Freedom to make life choices                              0.382245
# Generosity                                                0.020332
# Perceptions of corruption                                -0.310392
# depressive disorders                                      0.022363
# schooling                                                 0.753941
# alcohol disorders                                         0.022948
# suicide rates                                             0.403710
# Obesity                                                   0.536544
# Fertility                                                -0.841078
# Life Ladder                                               0.742652
# Year                                                      0.167449
#
#                                   Freedom to make life choices  Generosity  \
# Log GDP per capita                                    0.350144   -0.012443
# Social support                                        0.410429    0.060608
# Healthy life expectancy at birth                      0.382245    0.020332
# Freedom to make life choices                          1.000000    0.316374
# Generosity                                            0.316374    1.000000
# Perceptions of corruption                            -0.486243   -0.266746
# depressive disorders                                  0.070227   -0.021815
# schooling                                             0.294868   -0.052331
# alcohol disorders                                    -0.005968   -0.158028
# suicide rates                                         0.194362   -0.027952
# Obesity                                               0.002226   -0.261668
# Fertility                                            -0.265312    0.039904
# Life Ladder                                           0.524771    0.184295
# Year                                                  0.220855   -0.040584
#
#                                   Perceptions of corruption  \
# Log GDP per capita                                -0.358590
# Social support                                    -0.220657
# Healthy life expectancy at birth                  -0.310392
# Freedom to make life choices                      -0.486243
# Generosity                                        -0.266746
# Perceptions of corruption                          1.000000
# depressive disorders                               0.062425
# schooling                                         -0.253661
# alcohol disorders                                  0.055468
# suicide rates                                     -0.149239
# Obesity                                           -0.019936
# Fertility                                          0.128377
# Life Ladder                                       -0.448454
# Year                                              -0.092602
#
#                                   depressive disorders  schooling  \
# Log GDP per capita                           -0.017390   0.808098
# Social support                               -0.099335   0.627480
# Healthy life expectancy at birth              0.022363   0.753941
# Freedom to make life choices                  0.070227   0.294868
# Generosity                                   -0.021815  -0.052331
# Perceptions of corruption                     0.062425  -0.253661
# depressive disorders                          1.000000  -0.050058
# schooling                                    -0.050058   1.000000
# alcohol disorders                            -0.048300   0.233019
# suicide rates                                 0.059524   0.439511
# Obesity                                      -0.104259   0.575020
# Fertility                                    -0.087996  -0.751386
# Life Ladder                                  -0.037855   0.641239
# Year                                          0.006847   0.100254
#
#                                   alcohol disorders  suicide rates   Obesity  \
# Log GDP per capita                         0.077401       0.455973  0.580122
# Social support                             0.221118       0.380622  0.401096
# Healthy life expectancy at birth           0.022948       0.403710  0.536544
# Freedom to make life choices              -0.005968       0.194362  0.002226
# Generosity                                -0.158028      -0.027952 -0.261668
# Perceptions of corruption                  0.055468      -0.149239 -0.019936
# depressive disorders                      -0.048300       0.059524 -0.104259
# schooling                                  0.233019       0.439511  0.575020
# alcohol disorders                          1.000000       0.306994  0.199796
# suicide rates                              0.306994       1.000000  0.247636
# Obesity                                    0.199796       0.247636  1.000000
# Fertility                                 -0.169436      -0.460922 -0.622111
# Life Ladder                                0.104078       0.345760  0.360532
# Year                                      -0.060915      -0.050463  0.095079
#
#                                   Fertility  Life Ladder      Year
# Log GDP per capita                -0.781835     0.785219  0.084279
# Social support                    -0.553439     0.708796 -0.012660
# Healthy life expectancy at birth  -0.841078     0.742652  0.167449
# Freedom to make life choices      -0.265312     0.524771  0.220855
# Generosity                         0.039904     0.184295 -0.040584
# Perceptions of corruption          0.128377    -0.448454 -0.092602
# depressive disorders              -0.087996    -0.037855  0.006847
# schooling                         -0.751386     0.641239  0.100254
# alcohol disorders                 -0.169436     0.104078 -0.060915
# suicide rates                     -0.460922     0.345760 -0.050463
# Obesity                           -0.622111     0.360532  0.095079
# Fertility                          1.000000    -0.597945 -0.085903
# Life Ladder                       -0.597945     1.000000  0.031729
# Year                              -0.085903     0.031729  1.000000
# <AxesSubplot:>
