# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/pjt/happy_0814.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'schooling', 'alcohol', 'suicide',
#        'obesity', 'birth', 'mental', 'country_num', 'continent'],
#       dtype='object')

# %%
df=df[df['year']==2019]
df.head()
# Out:
#         country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 11  Afghanistan  2019  2.375    7.697   0.420      52.4    0.394      -0.108
# 23      Albania  2019  4.995    9.544   0.686      69.0    0.777      -0.099
# 32      Algeria  2019  4.745    9.337   0.803      66.1    0.385       0.005
# 50    Argentina  2019  6.086   10.000   0.896      69.0    0.817      -0.211
# 65      Armenia  2019  5.488    9.522   0.782      67.2    0.844      -0.172
#
#     corruption  schooling   alcohol   suicide  obesity  birth    mental  \
# 11       0.924        3.8  0.683062  0.761195     8.50  4.321  3.240075
# 23       0.914       10.0  0.437421  0.744028    12.11  1.597  4.968158
# 32       0.741        8.0  0.332953  1.011559    17.47  2.988  7.569434
# 50       0.830        9.9  1.705538  1.510640    11.41  2.247  6.974373
# 65       0.583       11.7  1.532459  1.066224    13.36  1.758  4.588087
#
#     country_num continent
# 11            4        AS
# 23            8        EU
# 32           12        AF
# 50           32        SA
# 65           51        AS

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['alcohol']])
df['kmeans']= kmeans.labels_
df[df['kmeans']==2]
# Out:
#          country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 441      Denmark  2019  7.693   10.954   0.958      72.7    0.963       0.020
# 541      Finland  2019  7.780   10.792   0.937      72.0    0.948      -0.052
# 678     Honduras  2019  5.930    8.653   0.797      67.4    0.846       0.063
# 857   Kazakhstan  2019  6.272   10.179   0.951      65.2    0.852      -0.055
# 898   Kyrgyzstan  2019  5.685    8.567   0.877      64.4    0.920      -0.002
# 921       Latvia  2019  5.970   10.336   0.936      67.1    0.698      -0.194
# 968    Lithuania  2019  6.064   10.518   0.918      67.9    0.780      -0.251
# 1089     Moldova  2019  5.803    9.475   0.809      65.7    0.784      -0.092
# 1205   Nicaragua  2019  6.113    8.595   0.874      67.8    0.883       0.029
# 1352      Poland  2019  6.242   10.407   0.878      69.7    0.883      -0.231
# 1502    Slovenia  2019  6.665   10.563   0.949      71.4    0.945      -0.102
#
#       corruption  schooling    alcohol   suicide  obesity  birth    mental  \
# 441        0.174       12.6   8.592318  1.281387     7.61  1.764  6.558833
# 541        0.195       12.4   6.979488  1.576410    10.93  1.483  6.749231
# 678        0.815        6.5   5.397524  0.792312    10.12  2.427  5.285983
# 857        0.708       11.8   8.692705  3.166981    16.55  2.733  4.567043
# 898        0.885       10.9   6.847603  1.753215    11.69  2.952  4.766255
# 921        0.789       12.8  10.690721  1.561139    15.99  1.732  3.904323
# 968        0.783       13.0   9.239072  2.524897    14.63  1.684  4.272880
# 1089       0.884       11.6   9.292130  1.553667    15.76  1.269  4.010255
# 1205       0.622        6.7   7.271933  1.606224    13.48  2.377  6.731602
# 1352       0.696       12.3   8.269126  1.718714    14.02  1.435  4.324274
# 1502       0.785       12.2   5.477074  2.161266    12.26  1.613  5.243949
#
#       country_num continent  kmeans
# 441           208        EU       2
# 541           246        EU       2
# 678           340     Nor.A       2
# 857           398        AS       2
# 898           417        AS       2
# 921           428        EU       2
# 968           440        EU       2
# 1089          498        EU       2
# 1205          558     Nor.A       2
# 1352          616        EU       2
# 1502          705        EU       2

# %%
#nnn

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['red','green','blue'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of alcohol 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
